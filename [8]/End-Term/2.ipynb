# %% [markdown]
# | # |Diagram Type | Diagram |
# |---|-------------|---------|
# | A | Repeat of the code | ![image.png](attachment:image.png) |
# | B | External References | ![image-2.png](attachment:image-2.png) |
# | C | Summary of the Code | ![image-2.png](attachment:image-2.png) |
# | D | Description of the Code Intent | ![image-3.png](attachment:image-3.png) |
# | E | Marker in The Code | ![E.png](attachment:E.png) |
# | F | Explanation of the Code | ![image-4.png](attachment:image-4.png) |
# | G | Repeat of the code | ![image-4.png](attachment:image-4.png) |
# | H | External References | ![image-5.png](attachment:image-5.png) |
# | I | Description of the Code Intent | ![image-6.png](attachment:image-6.png) |
# | J | Summary of the Code | ![image-7.png](attachment:image-7.png) |
# | K | Marker in The Code | ![image-8.png](attachment:image-8.png) |
# | L | Explanation of the Code | ![image-9.png](attachment:image-9.png) |
