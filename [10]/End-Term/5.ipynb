# %% [markdown]
# | # |Diagram Type | Diagram |
# |---|-------------|---------|
# | A | Class Diagram | ![image.png](attachment:image.png) |
# | B | Object Diagram | ![image-2.png](attachment:image-2.png) |
# | C | Profile Diagram | ![image-3.png](attachment:image-3.png) |
# | D | Use Case Diagram | ![image-4.png](attachment:image-4.png) |
# | E | Interaction Diagram (Sequence Diagram) | ![image-5.png](attachment:image-5.png) |
# | F | Component Diagram | ![image-6.png](attachment:image-6.png) |
