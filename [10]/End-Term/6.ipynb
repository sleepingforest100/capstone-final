# %% [markdown]
# ## P.S You can use the following website for running scripts: https://html-css-js.com/

# %% [markdown]
# ### A: [Cluttered Layout with Poor Color Choices]

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <title>Car Rental System - Mockup</title>
# <style>
# body {
# font-family: 'Comic Sans MS', sans-serif;
# background-color: lime;
# color: red;
# }
# header {
# background: orange;
# padding: 50px;
# text-align: left;
# }
# .hero {
# background: pink;
# padding: 100px;
# text-align: center;
# }
# .hero input {
# margin: 20px;
# padding: 5px;
# font-size: 24px;
# }
# .card {
# background: purple;
# color: yellow;
# margin: 50px;
# padding: 30px;
# border: 5px solid green;
# }
# </style>
# </head>
# <body>
# <header>
# <h1>Car Rental System</h1>
# </header>
# <section class="hero">
# <h2>Search for a Car</h2>
# <input type="text" placeholder="Type here">
# <input type="date">
# </section>
# <section class="cards">
# <div class="card">
# <h3>Car 1</h3>
# <p>Some details</p>
# </div>
# </section>
# </body>
# </html>

# %% [markdown]
# ### B: [Overlapping Elements and Misaligned Layout]

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <title>Car Rental System -2</title>
# <style>
# body {
# font-family: 'Times New Roman', serif;
# background-color: #fff;
# color: #000;
# }
# .container {
# position: relative;
# }
# header {
# background: #f00;
# padding: 10px;
# text-align: center;
# font-size: 30px;
# }
# .hero {
# position: absolute;
# top: 50px;
# left: 20px;
# width: 80%;
# background: rgba(0, 255, 0, 0.3);
# padding: 50px;
# }
# .hero input {
# display: block;
# margin: 20px auto;
# width: 50%;
# padding: 15px;
# }
# .card {
# width: 300px;
# background: yellow;
# float: left;
# margin: -30px 10px 50px 10px;
# padding: 10px;
# }
# </style>
# </head>
# <body>
# <div class="container">
# <header> Car Rental</header>
# <div class="hero">
# <h2>Book Your Car</h2>
# <input type="text" placeholder="Location">
# <input type="date">
# <input type="date">
# </div>
# <div class="card">
# <h3>Car A</h3>
# <p>Some details</p>
# </div>
# <div class="card">
# <h3>Car B</h3>
# <p>More details</p>
# </div>
# </div>
#
# </body>
# </html>

# %% [markdown]
# ### C: [Too Many Fonts and Distracting Animations]

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <title>Car Rental </title>
# <style>
# body {
# font-family: 'Courier New', monospace;
# background-color: #eee;
# color: black;
# }
# header {
# font-size: 50px;
# animation: colorChange 3s infinite;
# }
# @keyframes colorChange {
# 0% { color: blue; }
# 50% { color: red; }
# 100% { color: green; }
# }
# .hero {
# background: black;
# color: white;
# padding: 30px;
# text-align: center;
# font-size: 18px;
# }
# .card {
# font-family: 'Verdana', sans-serif;
# background: linear-gradient(to right, red, yellow);
# padding: 20px;
# margin: 20px;
# }
# </style>
# </head>
# <body>
# <header>Car Rental</header>
# <div class="hero">
# <h2>Find Your Dream Car!</h2>
# <input type="text" placeholder="Location">
# <input type="date">
# </div>
# <div class="card">
# <h3>Special Deal!</h3>
# <p>Details about the car.</p>
# </div>
# </body>
# </html>

# %% [markdown]
# ### D: [Good Case]

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <title>Car Rental System</title>
# <style>
# * {
# box-sizing: border-box;
# margin: 0;
# padding: 0;
# font-family: 'Arial', sans-serif;
# }
# body {
# background-color: #f4f8fb;
# color: #333;
# }
# header {
# background: #007bff;
# padding: 20px;
# text-align: center;
# color: white;
# }
# nav {
# display: flex;
# justify-content: center;
# padding: 10px;
# background: #0056b3;
# }
# nav a {
# color: white;
# text-decoration: none;
# margin: 0 15px;
# font-weight: bold;
# }
# nav a:hover {
# text-decoration: underline;
# }
# .hero {
# display: flex;
# flex-direction: column;
# align-items: center;
# justify-content: center;
# text-align: center;
# padding: 50px 20px;
# background: url('https://via.placeholder.com/1600x600') no-repeat center center/cover;
# }
# .hero h2 {
# font-size: 36px;
# color: #ffeb3b; /* Bright yellow for better visibility */
# text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7);
# margin-bottom: 20px;
# }
# .search-bar input {
# padding: 15px;
# margin: 5px;
# width: 250px;
# max-width: 100%;
# border-radius: 5px;
# border: 1px solid #ddd;
# }
#
# .cards {
# display: flex;
# flex-wrap: wrap;
# justify-content: center;
# padding: 20px;
# }
# .card {
# background: white;
# border-radius: 10px;
# box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);
# margin: 15px;
# padding: 20px;
# width: 300px;
# transition: transform 0.2s ease;
# }
# .card:hover {
# transform: translateY(-5px);
# }
# .card img {
# width: 100%;
# border-radius: 10px 10px 0 0;
# }
# .card h3 {
# margin: 15px 0 10px;
# }
# .button {
# display: block;
# text-align: center;
# padding: 10px;
# background: #007bff;
# color: white;
# text-decoration: none;
# border-radius: 5px;
# margin-top: 10px;
# }
# .button:hover {
# background: #0056b3;
# }
# @media (max-width: 768px) {
# .hero h2 {
# font-size: 28px;
# }
# .card {
# width: 100%;
# max-width: 350px;
# }
# }
# </style>
# </head>
# <body>
# <header>
# <h1>Car Rental System</h1>
# </header>
# <nav>
# <a href="#">Home</a>
# <a href="#">Browse Cars</a>
# <a href="#">My Bookings</a>
# <a href="#">Profile</a>
# </nav>
# <section class="hero">
# <h2>Find Your Perfect Car</h2>
# <div class="search-bar">
#
# <input type="text" placeholder="Enter location">
# <input type="date">
# <input type="date">
# </div>
# </section>
# <section class="cards">
# <div class="card">
# <img
# src="https://stimg.cardekho.com/images/carexteriorimages/630x420/Skoda/Kylaq/11528/1733225175669/
# front-left-side-47.jpg?impolicy=resize&imwidth=480" alt="Car Image">
# <h3>Car Name</h3>
# <p>Details about the car go here. Automatic, 4-seater, great mileage.</p>
# <a href="#" class="button">Book Now</a>
# </div>
# <div class="card">
#
# <img src="https://cars.tatamotors.com/content/dam/tml/pv/products/tiago/year-2025/ice/promoting-
# vc/lifestyle/lifestyle-02.jpg" alt="Car Image">
#
# <h3>Car Name</h3>
# <p>Details about the car go here. Manual, 5-seater, fuel-efficient.</p>
# <a href="#" class="button">Book Now</a>
# </div>
# <div class="card">
#
# <img src="https://www.usnews.com/object/image/00000191-d821-d8b8-adf7-f97944b10000/chevrolet-
# corvette-zr1-coupe-001.jpg?update-time=1725907944302&size=responsiveGallery" alt="Car Image">
#
# <h3>Car Name</h3>
# <p>Details about the car go here. SUV, spacious, family-friendly.</p>
# <a href="#" class="button">Book Now</a>
# </div>
# </section>
# </body>
# </html>

# %% [markdown]
# ### E: [Broken and Minimal Usability]

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <title>Car Rental UI</title>
# <style>
# body {
# background-color: gray;
# color: white;
# }
# .hero {
# height: 200px;
# overflow: hidden;
# padding: 0;
# text-align: left;
# }
# .hero input {
# width: 150%;
# padding: 5px;
# border: none;
# outline: none;
# }
# .card {
# display: none;
# }
# </style>
#
# </head>
# <body>
# <header>Rental System</header>
# <div class="hero">
# <h2>Enter Your Search</h2>
# <input type="text" placeholder="Location">
# <input type="date">
# </div>
# <div class="card">
# <h3>Hidden Car</h3>
# <p>Details you can't see!</p>
# </div>
# </body>
# </html>
