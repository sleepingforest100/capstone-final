# %% [markdown]
# | # | Document Name | Document |
# |---|---------------|----------|
# | 1 | User Requirements | ![image.png](attachment:image.png) |
# | 2 | Functional Requirements | ![image-2.png](attachment:image-2.png) |
# | 3 | Non-functional Requirements | ![image-3.png](attachment:image-3.png) |
# | 4 | Written High-Level Requirements | ![image-4.png](attachment:image-4.png) |
# | 5 | System Architecture | ![image-5.png](attachment:image-5.png) |
# | 6 | Database Design | ![image-6.png](attachment:image-6.png) |
# | 7 | Flow Chart | ![image-7.png](attachment:image-7.png) |
# | 8 | Sequence Diagram | ![image-8.png](attachment:image-8.png) |
# | 9 | Class Diagram | ![image-9.png](attachment:image-9.png) |
# | 10 | Use Case Diagram | ![image-10.png](attachment:image-10.png) |
